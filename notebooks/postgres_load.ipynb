# %%
# notebooks/example_notebook.ipynb
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('./scripts'))

# %%
from load_data import load_data_from_postgres, load_data_using_sqlalchemy

# %%
# Define your SQL query
query = "SELECT * FROM xdr_data;"  # Replace with your actual table name

# Load data from PostgreSQL
df = load_data_from_postgres(query)

# Display the first few rows of the dataframe
if df is not None:
    print("Successfully loaded the data")
else:
    print("Failed to load data.")
# Out:
# c:\Users\Admin.DESKTOP-M4R2VLU\Documents\2week2\2week\notebooks\load_data.py:37: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# Successfully loaded the data

# %%
df
# Out:
#            Bearer Id           Start  Start ms              End  End ms  \
# 0       1.311448e+19  4/25/2019 6:24      73.0   4/26/2019 4:59   121.0
# 1       7.349883e+18  4/25/2019 6:24     114.0  4/26/2019 10:15    30.0
# 2       7.277826e+18  4/25/2019 6:24     445.0   4/26/2019 6:24   384.0
# 3       7.277826e+18  4/25/2019 6:24     589.0   4/26/2019 2:28   807.0
# 4       7.277826e+18  4/25/2019 6:24      41.0  4/26/2019 21:56   619.0
# ...              ...             ...       ...              ...     ...
# 149996  1.304243e+19  4/25/2019 6:24     105.0   4/26/2019 6:24    54.0
# 149997  1.304243e+19  4/25/2019 6:24     619.0   4/26/2019 6:24   539.0
# 149998  7.349883e+18  4/25/2019 6:24     983.0   4/26/2019 5:10   145.0
# 149999  1.311448e+19  4/25/2019 6:24      73.0   4/26/2019 7:26   101.0
# 150000  6.917538e+18  4/25/2019 6:24     997.0   4/26/2019 6:24   163.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0         81306.0  2.082099e+14   3.368851e+10  8.662480e+13
# 1        100274.0  2.082015e+14   3.361779e+10  3.565631e+13
# 2         86399.0  2.082017e+14   3.365000e+10  8.637690e+13
# 3         72230.0  2.082018e+14   3.366528e+10  8.637690e+13
# 4        142312.0  2.082010e+14   3.375424e+10  3.534681e+13
# ...           ...           ...            ...           ...
# 149996    86399.0  2.082099e+14   3.364427e+10  3.573531e+13
# 149997    86399.0  2.082015e+14   3.368314e+10  3.563011e+13
# 149998    81960.0  2.082021e+14   3.366287e+10  3.534721e+13
# 149999    90126.0  2.082015e+14   3.368314e+10  3.563011e+13
# 150000    86403.0  2.082098e+14   3.366097e+10  3.567160e+13
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0                 T16267B  ...          14572941.0          21198556.0
# 1                 T31441A  ...          11891995.0           2873614.0
# 2                 D73303B  ...          19373476.0          12907848.0
# 3                 D21229A  ...           6037503.0           7728848.0
# 4                 T14897A  ...          20014815.0           4557701.0
# ...                   ...  ...                 ...                 ...
# 149996            T71979A  ...          12215612.0          18825271.0
# 149997            D21289C  ...           6788742.0          15141201.0
# 149998            D34453A  ...           6312620.0          21437913.0
# 149999            D21317B  ...           4521896.0           1596021.0
# 150000            G69555A  ...           2752470.0          21657399.0
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0                3908775.0          17925820.0        842384221.0
# 1               10519271.0          16829923.0        285448109.0
# 2               13830578.0          20683448.0        535609559.0
# 3               18634977.0          11053516.0        433027259.0
# 4                6193312.0           3270853.0        176675660.0
# ...                    ...                 ...                ...
# 149996           6656452.0           7474726.0        497839849.0
# 149997           2986586.0          20558626.0        140591159.0
# 149998          13128552.0          18254488.0        434389834.0
# 149999          14942993.0          19477166.0        516378860.0
# 150000          15878346.0           3356169.0        672998427.0
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0              12250738.0       124094792.0         6995415.0
# 1                290651.0       155008322.0         4250402.0
# 2               4964812.0       732709172.0         6929847.0
# 3              10485062.0       609305875.0        11260143.0
# 4              15069453.0       347875197.0          907515.0
# ...                   ...               ...               ...
# 149996          2960719.0       619132847.0         2726903.0
# 149997         14148007.0       283669938.0         8019270.0
# 149998         10777310.0       407596213.0        14055246.0
# 149999          4141350.0       617398022.0        10773656.0
# 150000           427690.0        74421133.0         6030773.0
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             59156104.0       875667493.0
# 1             28030478.0       319841615.0
# 2             49511011.0       582401724.0
# 3             43194274.0       463447347.0
# 4             24874060.0       218552248.0
# ...                  ...               ...
# 149996        33053118.0       523169991.0
# 149997        61058572.0       156141100.0
# 149998        68092183.0       461657616.0
# 149999        39379618.0       549762849.0
# 150000        32927368.0       697751511.0
#
# [150001 rows x 55 columns]

# %%
df
# Out:
#            Bearer Id           Start  Start ms              End  End ms  \
# 0       1.311448e+19  4/25/2019 6:24      73.0   4/26/2019 4:59   121.0
# 1       7.349883e+18  4/25/2019 6:24     114.0  4/26/2019 10:15    30.0
# 2       7.277826e+18  4/25/2019 6:24     445.0   4/26/2019 6:24   384.0
# 3       7.277826e+18  4/25/2019 6:24     589.0   4/26/2019 2:28   807.0
# 4       7.277826e+18  4/25/2019 6:24      41.0  4/26/2019 21:56   619.0
# ...              ...             ...       ...              ...     ...
# 149996  1.304243e+19  4/25/2019 6:24     105.0   4/26/2019 6:24    54.0
# 149997  1.304243e+19  4/25/2019 6:24     619.0   4/26/2019 6:24   539.0
# 149998  7.349883e+18  4/25/2019 6:24     983.0   4/26/2019 5:10   145.0
# 149999  1.311448e+19  4/25/2019 6:24      73.0   4/26/2019 7:26   101.0
# 150000  6.917538e+18  4/25/2019 6:24     997.0   4/26/2019 6:24   163.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0         81306.0  2.082099e+14   3.368851e+10  8.662480e+13
# 1        100274.0  2.082015e+14   3.361779e+10  3.565631e+13
# 2         86399.0  2.082017e+14   3.365000e+10  8.637690e+13
# 3         72230.0  2.082018e+14   3.366528e+10  8.637690e+13
# 4        142312.0  2.082010e+14   3.375424e+10  3.534681e+13
# ...           ...           ...            ...           ...
# 149996    86399.0  2.082099e+14   3.364427e+10  3.573531e+13
# 149997    86399.0  2.082015e+14   3.368314e+10  3.563011e+13
# 149998    81960.0  2.082021e+14   3.366287e+10  3.534721e+13
# 149999    90126.0  2.082015e+14   3.368314e+10  3.563011e+13
# 150000    86403.0  2.082098e+14   3.366097e+10  3.567160e+13
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0                 T16267B  ...          14572941.0          21198556.0
# 1                 T31441A  ...          11891995.0           2873614.0
# 2                 D73303B  ...          19373476.0          12907848.0
# 3                 D21229A  ...           6037503.0           7728848.0
# 4                 T14897A  ...          20014815.0           4557701.0
# ...                   ...  ...                 ...                 ...
# 149996            T71979A  ...          12215612.0          18825271.0
# 149997            D21289C  ...           6788742.0          15141201.0
# 149998            D34453A  ...           6312620.0          21437913.0
# 149999            D21317B  ...           4521896.0           1596021.0
# 150000            G69555A  ...           2752470.0          21657399.0
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0                3908775.0          17925820.0        842384221.0
# 1               10519271.0          16829923.0        285448109.0
# 2               13830578.0          20683448.0        535609559.0
# 3               18634977.0          11053516.0        433027259.0
# 4                6193312.0           3270853.0        176675660.0
# ...                    ...                 ...                ...
# 149996           6656452.0           7474726.0        497839849.0
# 149997           2986586.0          20558626.0        140591159.0
# 149998          13128552.0          18254488.0        434389834.0
# 149999          14942993.0          19477166.0        516378860.0
# 150000          15878346.0           3356169.0        672998427.0
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0              12250738.0       124094792.0         6995415.0
# 1                290651.0       155008322.0         4250402.0
# 2               4964812.0       732709172.0         6929847.0
# 3              10485062.0       609305875.0        11260143.0
# 4              15069453.0       347875197.0          907515.0
# ...                   ...               ...               ...
# 149996          2960719.0       619132847.0         2726903.0
# 149997         14148007.0       283669938.0         8019270.0
# 149998         10777310.0       407596213.0        14055246.0
# 149999          4141350.0       617398022.0        10773656.0
# 150000           427690.0        74421133.0         6030773.0
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             59156104.0       875667493.0
# 1             28030478.0       319841615.0
# 2             49511011.0       582401724.0
# 3             43194274.0       463447347.0
# 4             24874060.0       218552248.0
# ...                  ...               ...
# 149996        33053118.0       523169991.0
# 149997        61058572.0       156141100.0
# 149998        68092183.0       461657616.0
# 149999        39379618.0       549762849.0
# 150000        32927368.0       697751511.0
#
# [150001 rows x 55 columns]

# %%
df.dtypes
# Out:
# Bearer Id                                   float64
# Start                                        object
# Start ms                                    float64
# End                                          object
# End ms                                      float64
# Dur. (ms)                                   float64
# IMSI                                        float64
# MSISDN/Number                               float64
# IMEI                                        float64
# Last Location Name                           object
# Avg RTT DL (ms)                             float64
# Avg RTT UL (ms)                             float64
# Avg Bearer TP DL (kbps)                     float64
# Avg Bearer TP UL (kbps)                     float64
# TCP DL Retrans. Vol (Bytes)                 float64
# TCP UL Retrans. Vol (Bytes)                 float64
# DL TP < 50 Kbps (%)                         float64
# 50 Kbps < DL TP < 250 Kbps (%)              float64
# 250 Kbps < DL TP < 1 Mbps (%)               float64
# DL TP > 1 Mbps (%)                          float64
# UL TP < 10 Kbps (%)                         float64
# 10 Kbps < UL TP < 50 Kbps (%)               float64
# 50 Kbps < UL TP < 300 Kbps (%)              float64
# UL TP > 300 Kbps (%)                        float64
# HTTP DL (Bytes)                             float64
# HTTP UL (Bytes)                             float64
# Activity Duration DL (ms)                   float64
# Activity Duration UL (ms)                   float64
# Dur. (ms).1                                 float64
# Handset Manufacturer                         object
# Handset Type                                 object
# Nb of sec with 125000B < Vol DL             float64
# Nb of sec with 1250B < Vol UL < 6250B       float64
# Nb of sec with 31250B < Vol DL < 125000B    float64
# Nb of sec with 37500B < Vol UL              float64
# Nb of sec with 6250B < Vol DL < 31250B      float64
# Nb of sec with 6250B < Vol UL < 37500B      float64
# Nb of sec with Vol DL < 6250B               float64
# Nb of sec with Vol UL < 1250B               float64
# Social Media DL (Bytes)                     float64
# Social Media UL (Bytes)                     float64
# Google DL (Bytes)                           float64
# Google UL (Bytes)                           float64
# Email DL (Bytes)                            float64
# Email UL (Bytes)                            float64
# Youtube DL (Bytes)                          float64
# Youtube UL (Bytes)                          float64
# Netflix DL (Bytes)                          float64
# Netflix UL (Bytes)                          float64
# Gaming DL (Bytes)                           float64
# Gaming UL (Bytes)                           float64
# Other DL (Bytes)                            float64
# Other UL (Bytes)                            float64
# Total UL (Bytes)                            float64
# Total DL (Bytes)                            float64
# dtype: object

# %%
df.isnull().any()
# Out:
# Bearer Id                                    True
# Start                                        True
# Start ms                                     True
# End                                          True
# End ms                                       True
# Dur. (ms)                                    True
# IMSI                                         True
# MSISDN/Number                                True
# IMEI                                         True
# Last Location Name                           True
# Avg RTT DL (ms)                              True
# Avg RTT UL (ms)                              True
# Avg Bearer TP DL (kbps)                      True
# Avg Bearer TP UL (kbps)                      True
# TCP DL Retrans. Vol (Bytes)                  True
# TCP UL Retrans. Vol (Bytes)                  True
# DL TP < 50 Kbps (%)                          True
# 50 Kbps < DL TP < 250 Kbps (%)               True
# 250 Kbps < DL TP < 1 Mbps (%)                True
# DL TP > 1 Mbps (%)                           True
# UL TP < 10 Kbps (%)                          True
# 10 Kbps < UL TP < 50 Kbps (%)                True
# 50 Kbps < UL TP < 300 Kbps (%)               True
# UL TP > 300 Kbps (%)                         True
# HTTP DL (Bytes)                              True
# HTTP UL (Bytes)                              True
# Activity Duration DL (ms)                    True
# Activity Duration UL (ms)                    True
# Dur. (ms).1                                  True
# Handset Manufacturer                         True
# Handset Type                                 True
# Nb of sec with 125000B < Vol DL              True
# Nb of sec with 1250B < Vol UL < 6250B        True
# Nb of sec with 31250B < Vol DL < 125000B     True
# Nb of sec with 37500B < Vol UL               True
# Nb of sec with 6250B < Vol DL < 31250B       True
# Nb of sec with 6250B < Vol UL < 37500B       True
# Nb of sec with Vol DL < 6250B                True
# Nb of sec with Vol UL < 1250B                True
# Social Media DL (Bytes)                     False
# Social Media UL (Bytes)                     False
# Google DL (Bytes)                           False
# Google UL (Bytes)                           False
# Email DL (Bytes)                            False
# Email UL (Bytes)                            False
# Youtube DL (Bytes)                          False
# Youtube UL (Bytes)                          False
# Netflix DL (Bytes)                          False
# Netflix UL (Bytes)                          False
# Gaming DL (Bytes)                           False
# Gaming UL (Bytes)                           False
# Other DL (Bytes)                            False
# Other UL (Bytes)                            False
# Total UL (Bytes)                             True
# Total DL (Bytes)                             True
# dtype: bool

# %%
df=df_filled_ffill = df.fillna(0)
df
# Out:
#            Bearer Id           Start  Start ms              End  End ms  \
# 0       1.311448e+19  4/25/2019 6:24      73.0   4/26/2019 4:59   121.0
# 1       7.349883e+18  4/25/2019 6:24     114.0  4/26/2019 10:15    30.0
# 2       7.277826e+18  4/25/2019 6:24     445.0   4/26/2019 6:24   384.0
# 3       7.277826e+18  4/25/2019 6:24     589.0   4/26/2019 2:28   807.0
# 4       7.277826e+18  4/25/2019 6:24      41.0  4/26/2019 21:56   619.0
# ...              ...             ...       ...              ...     ...
# 149996  1.304243e+19  4/25/2019 6:24     105.0   4/26/2019 6:24    54.0
# 149997  1.304243e+19  4/25/2019 6:24     619.0   4/26/2019 6:24   539.0
# 149998  7.349883e+18  4/25/2019 6:24     983.0   4/26/2019 5:10   145.0
# 149999  1.311448e+19  4/25/2019 6:24      73.0   4/26/2019 7:26   101.0
# 150000  6.917538e+18  4/25/2019 6:24     997.0   4/26/2019 6:24   163.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0         81306.0  2.082099e+14   3.368851e+10  8.662480e+13
# 1        100274.0  2.082015e+14   3.361779e+10  3.565631e+13
# 2         86399.0  2.082017e+14   3.365000e+10  8.637690e+13
# 3         72230.0  2.082018e+14   3.366528e+10  8.637690e+13
# 4        142312.0  2.082010e+14   3.375424e+10  3.534681e+13
# ...           ...           ...            ...           ...
# 149996    86399.0  2.082099e+14   3.364427e+10  3.573531e+13
# 149997    86399.0  2.082015e+14   3.368314e+10  3.563011e+13
# 149998    81960.0  2.082021e+14   3.366287e+10  3.534721e+13
# 149999    90126.0  2.082015e+14   3.368314e+10  3.563011e+13
# 150000    86403.0  2.082098e+14   3.366097e+10  3.567160e+13
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0                 T16267B  ...          14572941.0          21198556.0
# 1                 T31441A  ...          11891995.0           2873614.0
# 2                 D73303B  ...          19373476.0          12907848.0
# 3                 D21229A  ...           6037503.0           7728848.0
# 4                 T14897A  ...          20014815.0           4557701.0
# ...                   ...  ...                 ...                 ...
# 149996            T71979A  ...          12215612.0          18825271.0
# 149997            D21289C  ...           6788742.0          15141201.0
# 149998            D34453A  ...           6312620.0          21437913.0
# 149999            D21317B  ...           4521896.0           1596021.0
# 150000            G69555A  ...           2752470.0          21657399.0
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0                3908775.0          17925820.0        842384221.0
# 1               10519271.0          16829923.0        285448109.0
# 2               13830578.0          20683448.0        535609559.0
# 3               18634977.0          11053516.0        433027259.0
# 4                6193312.0           3270853.0        176675660.0
# ...                    ...                 ...                ...
# 149996           6656452.0           7474726.0        497839849.0
# 149997           2986586.0          20558626.0        140591159.0
# 149998          13128552.0          18254488.0        434389834.0
# 149999          14942993.0          19477166.0        516378860.0
# 150000          15878346.0           3356169.0        672998427.0
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0              12250738.0       124094792.0         6995415.0
# 1                290651.0       155008322.0         4250402.0
# 2               4964812.0       732709172.0         6929847.0
# 3              10485062.0       609305875.0        11260143.0
# 4              15069453.0       347875197.0          907515.0
# ...                   ...               ...               ...
# 149996          2960719.0       619132847.0         2726903.0
# 149997         14148007.0       283669938.0         8019270.0
# 149998         10777310.0       407596213.0        14055246.0
# 149999          4141350.0       617398022.0        10773656.0
# 150000           427690.0        74421133.0         6030773.0
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             59156104.0       875667493.0
# 1             28030478.0       319841615.0
# 2             49511011.0       582401724.0
# 3             43194274.0       463447347.0
# 4             24874060.0       218552248.0
# ...                  ...               ...
# 149996        33053118.0       523169991.0
# 149997        61058572.0       156141100.0
# 149998        68092183.0       461657616.0
# 149999        39379618.0       549762849.0
# 150000        32927368.0       697751511.0
#
# [150001 rows x 55 columns]

# %%
# Top 10 Handsets
top_handsets = df['Handset Type'].value_counts().head(10)
#Top 3 Handset Manufacturers
top_manufacturers = df['Handset Manufacturer'].value_counts().head(3)

#  Top 5 Handsets per Top 3 Handset Manufacturer
top_handsets_per_manufacturer = {}
for manufacturer in top_manufacturers.index:
    handsets = df[df['Handset Manufacturer'] == manufacturer]['Handset Type'].value_counts().head(5)
    top_handsets_per_manufacturer[manufacturer] = handsets

    # Display Results
print("Top 10 Handsets Used by Customers:\n", top_handsets)
print("\nTop 3 Handset Manufacturers:\n", top_manufacturers)
print("\nTop 5 Handsets per Top 3 Handset Manufacturer:")
for manufacturer, handsets in top_handsets_per_manufacturer.items():
    print(f"\n{manufacturer}:\n{handsets}")

# Interpretation and Recommendations
print("\nInterpretation and Recommendations:")
print("1. Samsung is the leading manufacturer with a diverse range of handsets.")
print("2. Consider marketing campaigns focused on the top models identified.")
print("3. Investigate the 'undefined' category for better data quality.")
print("4. Monitor trends and adjust strategies based on customer preferences.")
# Out:
# Top 10 Handsets Used by Customers:
#  Handset Type
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: count, dtype: int64
#
# Top 3 Handset Manufacturers:
#  Handset Manufacturer
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: count, dtype: int64
#
# Top 5 Handsets per Top 3 Handset Manufacturer:
#
# Apple:
# Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: count, dtype: int64
#
# Samsung:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: count, dtype: int64
#
# Huawei:
# Handset Type
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: count, dtype: int64
#
# Interpretation and Recommendations:
# 1. Samsung is the leading manufacturer with a diverse range of handsets.
# 2. Consider marketing campaigns focused on the top models identified.
# 3. Investigate the 'undefined' category for better data quality.
# 4. Monitor trends and adjust strategies based on customer preferences.

# %%
#data selction
query = "SELECT Bearer Id,Session Duration,Social Media DL,Social Media UL,Google DL,Google UL,Email DL,Email UL,YouTube DL,YouTube UL,Netflix DL,Netflix UL,Gaming DL,Gaming UL,Other DL,Other UL FROM xdr_data;"
df = df = load_data_using_sqlalchemy(query)

try:
    df = pd.read_sql(query, engine)
    print("Data loaded successfully!")
    print(df.head())  # Display the first few rows of the DataFrame
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near "DL"
# LINE 1: SELECT Bearer Id,Session Duration,Social Media DL,Social Med...
#                                                        ^
#
# [SQL: SELECT Bearer Id,Session Duration,Social Media DL,Social Media UL,Google DL,Google UL,Email DL,Email UL,YouTube DL,YouTube UL,Netflix DL,Netflix UL,Gaming DL,Gaming UL,Other DL,Other UL FROM xdr_data;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# An error occurred: name 'engine' is not defined

# %%
data = {
    'Bearer Id',
    'Session Duration',
    'Social Media DL',
    'Social Media UL',
    'Google DL',
    'Google UL',
    'Email DL',
    'Email UL',
    'YouTube DL',
    'YouTube UL',
    'Netflix DL',
    'Netflix UL',
    'Gaming DL',
    'Gaming UL',
    'Other DL',
    'Other UL',
}

df = pd.DataFrame(data)



# Check existing columns
print("Current columns in DataFrame:", df.columns.tolist())

# Adjust the aggregation code to use the correct existing column names
try:
    aggregated_data = df.groupby('Bearer Id').agg(
        Number_of_Sessions=('Bearer Id', 'size'),
        Total_Session_Duration=('Session Duration (ms)', 'sum'),
        Total_Social_Media_DL=('Social Media DL (Bytes)', 'sum'),
        Total_Social_Media_UL=('Social Media UL (Bytes)', 'sum'),
        Total_Google_DL=('Google DL (Bytes)', 'sum'),
        Total_Google_UL=('Google UL (Bytes)', 'sum'),
        Total_Email_DL=('Email DL (Bytes)', 'sum'),
        Total_Email_UL=('Email UL (Bytes)', 'sum'),
        Total_YouTube_DL=('YouTube DL (Bytes)', 'sum'),
        Total_YouTube_UL=('YouTube UL (Bytes)', 'sum'),
        Total_Netflix_DL=('Netflix DL (Bytes)', 'sum'),
        Total_Netflix_UL=('Netflix UL (Bytes)', 'sum'),
        Total_Gaming_DL=('Gaming DL (Bytes)', 'sum'),
        Total_Gaming_UL=('Gaming UL (Bytes)', 'sum'),
        #Total_Other_DL=('Other DL (Bytes)', 'sum'),
        #Total_Other_UL=('Other UL (Bytes)', 'sum'),
    ).reset_index()
    
    print(aggregated_data)
except KeyError as e:
    print(f"KeyError: {e}. Please check the column names.")
# Out:
# Current columns in DataFrame: [0]
# KeyError: 'Bearer Id'. Please check the column names.
